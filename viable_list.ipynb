# %%
import sympy as sy
x = sy.Symbol('x')
from fitness import fit_fun
from sympy.functions.elementary.trigonometric import atan as atan
from sympy.functions.elementary.trigonometric import sin as sin
from sympy.functions.elementary.trigonometric import cos as cos
from sympy.functions.elementary.trigonometric import tan as tan
from sympy.functions.elementary.hyperbolic import sinh as sinh
from sympy.functions.elementary.hyperbolic import cosh as cosh
from sympy.functions.elementary.hyperbolic import tanh as tanh

# %%
fit_fun(1.0e-10*tanh(cosh(tanh(x))))
# Out:
# Current function:  1.0e-10*tanh(cosh(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.27199999999953
# Phi_min = 3.9968028886505635e-15
# (Start point, End point) = (-8.27199999999953, -1.5399999999999971)
# efold = 1471977.112256441
# N_star = 53.8264142554041
# phi_star = -3.1959999999999984
# n_star = 0.9648196703045199
# r_star = 0.0006115334891792986
# m_star = 0.025045282076328144
# fitness =  [0, 0]
# Phi at the end of iteration = 8.271999999999537
# Phi_min = 3.9968028886505635e-15
# (Start point, End point) = (8.271999999999537, 1.5400000000000051)
# efold = 1471977.1122564408
# N_star = 53.8264142554041
# phi_star = 3.1960000000000064
# n_star = 0.9648196703045199
# r_star = 0.0006115334891792986
# m_star = 0.025045282076328144
# [0, 0]
# 0

# %%
fit_fun(1.0e-10*cosh(x)/sy.sqrt(cosh(x)**2 + 1))
# Out:
# Current function:  1.0e-10*cosh(x)/sqrt(cosh(x)**2 + 1)
# fitness =  0
# Phi at the end of iteration = -8.587999999999496
# Phi_min = 1.7763568394002505e-15
# (Start point, End point) = (-8.587999999999496, -1.8359999999999996)
# efold = 1054535.9759660743
# N_star = 53.92982246164764
# phi_star = -3.664000000000001
# n_star = 0.9641844979371698
# r_star = 0.0006411610357285433
# m_star = 0.02920646824071881
# fitness =  [0, 0]
# Phi at the end of iteration = 8.5879999999995
# Phi_min = 1.7763568394002505e-15
# (Start point, End point) = (8.5879999999995, 1.8360000000000032)
# efold = 1054535.9757969785
# N_star = 53.92982246164764
# phi_star = 3.6640000000000046
# n_star = 0.9641844979371662
# r_star = 0.000641161035728543
# m_star = 0.02920646824071882
# [0, 0]
# 0

# %%
fit_fun(1.0e-10*atan(cosh(tanh(x))))
# Out:
# Current function:  1.0e-10*atan(cosh(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.307999999999529
# Phi_min = -8.881784197001252e-16
# (Start point, End point) = (-8.307999999999529, -1.600000000000002)
# efold = 1244861.0647557052
# N_star = 53.87974157258802
# phi_star = -3.3080000000000034
# n_star = 0.9644558633816716
# r_star = 0.0006275268712874204
# m_star = 0.027033275647345766
# fitness =  [0, 0]
# Phi at the end of iteration = 8.307999999999527
# Phi_min = -8.881784197001252e-16
# (Start point, End point) = (8.307999999999527, 1.6000000000000003)
# efold = 1244861.0647557052
# N_star = 53.87974157258802
# phi_star = 3.3080000000000016
# n_star = 0.9644558633816716
# r_star = 0.0006275268712874204
# m_star = 0.027033275647345766
# [0, 0]
# 0

# %%
fit_fun(1.0e-10*cosh(atan(cosh(x))))
# Out:
# Current function:  1.0e-10*cosh(atan(cosh(x)))
# fitness =  0
# Phi at the end of iteration = -15.219999999998768
# Phi_min = -2.220446049250313e-16
# (Start point, End point) = (-15.219999999998768, -1.5680000000000014)
# efold = 1048374.8763243537
# N_star = 54.037243203358074
# phi_star = -5.399999999999849
# n_star = 0.9640544848404516
# r_star = 0.002501558665802793
# m_star = 0.029373438548109036
# fitness =  [0, 0]
# Phi at the end of iteration = 15.219999999998768
# Phi_min = -2.220446049250313e-16
# (Start point, End point) = (15.219999999998768, 1.568000000000001)
# efold = 1048374.8763243537
# N_star = 54.037243203358074
# phi_star = 5.3999999999998485
# n_star = 0.9640544848404516
# r_star = 0.0025015586658027975
# m_star = 0.029373438548109025
# [0, 0]
# 0

# %%
fit_fun(1.0e-10*sinh(sinh(atan(x))))
# Out:
# Current function:  1.0e-10*sinh(sinh(atan(x)))
# fitness =  [-5.030571626955051, 0]
# Phi at the end of iteration = 20.0000052892837
# Phi_min = -4.999994710716215
# (Start point, End point) = (20, -3.8079947107163243)
# efold = 1968.8187639900657
# N_star = 53.9982469943406
# phi_star = 4.756005289283599
# n_star = 0.9677792208761278
# r_star = 0.01687839490562532
# m_star = 0.027600334946492604
# [-5.030571626955051, 0]
# 0

# %%
fit_fun(0.5e-10*cos(cos(tanh(x))))
# Out:
# Current function:  5.0e-11*cos(cos(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.28399999999953
# Phi_min = 1.3322676295501878e-15
# (Start point, End point) = (-8.28399999999953, -1.5599999999999998)
# efold = 1436700.7191725757
# N_star = 53.83446810998451
# phi_star = -3.220000000000001
# n_star = 0.9648249550962394
# r_star = 0.0006115998063011858
# m_star = 0.025353187382583114
# fitness =  [0, 0]
# Phi at the end of iteration = 8.283999999999534
# Phi_min = 1.3322676295501878e-15
# (Start point, End point) = (8.283999999999534, 1.5600000000000025)
# efold = 1436700.719172576
# N_star = 53.83446810998451
# phi_star = 3.2200000000000037
# n_star = 0.9648249550962407
# r_star = 0.0006115998063011431
# m_star = 0.025353187382583558
# [0, 0]
# 0

# %%
fit_fun(2e-10*atan(atan(cosh(x))))
# Out:
# Current function:  2.0e-10*atan(atan(cosh(x)))
# fitness =  0
# Phi at the end of iteration = -14.675999999998828
# Phi_min = 4.440892098500626e-16
# (Start point, End point) = (-14.675999999998828, -1.5920000000000007)
# efold = 1385894.7321251014
# N_star = 54.017415561430234
# phi_star = -4.671999999999929
# n_star = 0.9656929883103732
# r_star = 0.002174144650198288
# m_star = 0.026452646109818307
# fitness =  [0, 0]
# Phi at the end of iteration = 14.675999999998828
# Phi_min = 4.440892098500626e-16
# (Start point, End point) = (14.675999999998828, 1.5920000000000016)
# efold = 1385894.732125099
# N_star = 54.017415561430234
# phi_star = 4.6719999999999295
# n_star = 0.9656929883103732
# r_star = 0.002174144650198284
# m_star = 0.026452646109818317
# [0, 0]
# 0

# %%
fit_fun(2.5e-10*tanh(atan(cosh(x))))
# Out:
# Current function:  2.5e-10*tanh(atan(cosh(x)))
# fitness =  0
# Phi at the end of iteration = -14.355999999998861
# Phi_min = 1.5543122344752192e-15
# (Start point, End point) = (-14.355999999998861, -1.6959999999999997)
# efold = 1412486.585202366
# N_star = 54.035380938075896
# phi_star = -4.411999999999956
# n_star = 0.9666804334689874
# r_star = 0.0019552082062230546
# m_star = 0.026938717986493145
# fitness =  [0, 0]
# Phi at the end of iteration = 14.355999999998865
# Phi_min = 1.5543122344752192e-15
# (Start point, End point) = (14.355999999998865, 1.6960000000000028)
# efold = 1412486.5852023687
# N_star = 54.035380938075896
# phi_star = 4.411999999999959
# n_star = 0.9666804334689875
# r_star = 0.0019552082062230434
# m_star = 0.026938717986493183
# [0, 0]
# 0

# %%
fit_fun(0.5e-10*cos(1/cosh(x)))
# Out:
# Current function:  5.0e-11*cos(1/cosh(x))
# fitness =  0
# Phi at the end of iteration = -8.423999999999515
# Phi_min = 2.4424906541753444e-15
# (Start point, End point) = (-8.423999999999515, -1.6879999999999988)
# efold = 1192271.7262652542
# N_star = 53.892633997219974
# phi_star = -3.4440000000000004
# n_star = 0.9644440784888759
# r_star = 0.0006297178570217532
# m_star = 0.02761355736545785
# fitness =  [0, 0]
# Phi at the end of iteration = 8.423999999999518
# Phi_min = 2.4424906541753444e-15
# (Start point, End point) = (8.423999999999518, 1.6880000000000037)
# efold = 1192271.7262652623
# N_star = 53.89263399721998
# phi_star = 3.4440000000000053
# n_star = 0.9644440784888764
# r_star = 0.0006297178570217409
# m_star = 0.027613557365457984
# [0, 0]
# 0

# %%
fit_fun(0.5e-10*sin(cosh(tanh(x))))
# Out:
# Current function:  5.0e-11*sin(cosh(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -7.51199999999961
# Phi_min = 6.661338147750939e-15
# (Start point, End point) = (-7.51199999999961, -1.4919999999999944)
# efold = 2031947.8779399332
# N_star = 53.73017569358716
# phi_star = -2.611999999999995
# n_star = 0.9675951228017958
# r_star = 0.00031708478252502094
# m_star = 0.025116006951340596
# fitness =  [0, 0]
# Phi at the end of iteration = 7.511999999999623
# Phi_min = 6.661338147750939e-15
# (Start point, End point) = (7.511999999999623, 1.4920000000000078)
# efold = 2031947.8779399337
# N_star = 53.73017569358716
# phi_star = 2.6120000000000085
# n_star = 0.9675951228017973
# r_star = 0.0003170847825249943
# m_star = 0.025116006951341124
# [0, 0]
# 0

# %%
fit_fun(0.5e-10*cosh(tanh(tanh(x))))
# Out:
# Current function:  5.0e-11*cosh(tanh(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.211999999999536
# Phi_min = 4.218847493575595e-15
# (Start point, End point) = (-8.211999999999536, -1.4919999999999969)
# efold = 1468664.598449992
# N_star = 53.82805407017657
# phi_star = -3.1359999999999983
# n_star = 0.9647339414669382
# r_star = 0.000614399278505292
# m_star = 0.02506179181400688
# fitness =  [0, 0]
# Phi at the end of iteration = 8.211999999999543
# Phi_min = 4.218847493575595e-15
# (Start point, End point) = (8.211999999999543, 1.4920000000000053)
# efold = 1468664.5984499918
# N_star = 53.82805407017657
# phi_star = 3.136000000000007
# n_star = 0.9647339414669382
# r_star = 0.000614399278505292
# m_star = 0.02506179181400688
# [0, 0]
# 0

# %%
fit_fun(0.5e-10*cosh(atan(tanh(x))))
# Out:
# Current function:  5.0e-11*cosh(atan(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.26799999999953
# Phi_min = 3.774758283725532e-15
# (Start point, End point) = (-8.26799999999953, -1.5199999999999974)
# efold = 1418854.6006496793
# N_star = 53.83738011485777
# phi_star = -3.203999999999999
# n_star = 0.9644999220464967
# r_star = 0.0006249841860109452
# m_star = 0.02536098034292308
# fitness =  [0, 0]
# Phi at the end of iteration = 8.267999999999537
# Phi_min = 3.774758283725532e-15
# (Start point, End point) = (8.267999999999537, 1.520000000000005)
# efold = 1418854.6006496793
# N_star = 53.83738011485777
# phi_star = 3.2040000000000064
# n_star = 0.964499922046498
# r_star = 0.0006249841860109033
# m_star = 0.025360980342923507
# [0, 0]
# 0

# %%
fit_fun(0.5e-10*cosh(sin(tanh(x))))
# Out:
# Current function:  5.0e-11*cosh(sin(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.239999999999533
# Phi_min = 3.1086244689504383e-15
# (Start point, End point) = (-8.239999999999533, -1.555999999999998)
# efold = 1320797.6340021228
# N_star = 53.86243163836627
# phi_star = -3.2159999999999993
# n_star = 0.9646766465646665
# r_star = 0.0006167046892371806
# m_star = 0.02638812938425275
# fitness =  [0, 0]
# Phi at the end of iteration = 8.23999999999954
# Phi_min = 3.1086244689504383e-15
# (Start point, End point) = (8.23999999999954, 1.5560000000000043)
# efold = 1320797.6340021228
# N_star = 53.86243163836627
# phi_star = 3.2160000000000055
# n_star = 0.9646766465646665
# r_star = 0.0006167046892371806
# m_star = 0.02638812938425275
# [0, 0]
# 0

# %%
fit_fun(1.5e-10*x/cosh(x))
# Out:
# Current function:  1.5e-10*x/cosh(x)
# fitness =  0
# Phi at the end of iteration = -17.883679407313572
# Phi_min = -1.1996794073142627
# (Start point, End point) = (-17.883679407313572, -2.4476794073142636)
# efold = 1225091.762677479
# N_star = 53.99378816140758
# phi_star = -6.727679407313965
# n_star = 0.9636357540963443
# r_star = 0.00359914286957165
# m_star = 0.02562521652293014
# [0, -10.004913175434956]
# 0

# %%
fit_fun(0.5e-10*atan(1/sinh(x)))
# Out:
# Current function:  5.0e-11*atan(1/sinh(x))
# fitness =  0
# Phi at the end of iteration = -14.312002687451368
# Phi_min = -2.687452500106651e-06
# (Start point, End point) = (-14.312002687451368, -1.1360026874525009)
# efold = 1290350.6533300327
# N_star = 54.03817819628587
# phi_star = -4.332002687452467
# n_star = 0.9651159628961268
# r_star = 0.0023157265514946687
# m_star = 0.0270270442112473
# [0, -10.803755260446223]
# 0

# %%
fit_fun(0.5e-10*sinh(atan(cosh(x))))
# Out:
# Current function:  5.0e-11*sinh(atan(cosh(x)))
# fitness =  0
# Phi at the end of iteration = -15.36799999999875
# Phi_min = 1.1102230246251565e-15
# (Start point, End point) = (-15.36799999999875, -1.488)
# efold = 1348363.5879243016
# N_star = 53.95552630192766
# phi_star = -5.299999999999859
# n_star = 0.9641427743184041
# r_star = 0.0024864402874143956
# m_star = 0.025942095679098515
# fitness =  [0, 0]
# Phi at the end of iteration = 15.367999999998753
# Phi_min = 1.1102230246251565e-15
# (Start point, End point) = (15.367999999998753, 1.4880000000000022)
# efold = 1348363.5879243056
# N_star = 53.95552630192766
# phi_star = 5.299999999999861
# n_star = 0.9641427743184042
# r_star = 0.0024864402874143817
# m_star = 0.02594209567909855
# [0, 0]
# 0

# %%
fit_fun(0.5e-10*cosh(atan(sinh(x))))
# Out:
# Current function:  5.0e-11*cosh(atan(sinh(x)))
# fitness =  0
# Phi at the end of iteration = -15.20399999999877
# Phi_min = 6.661338147750939e-16
# (Start point, End point) = (-15.20399999999877, -1.3520000000000003)
# efold = 1314465.4245659418
# N_star = 53.967720972325026
# phi_star = -5.151999999999876
# n_star = 0.9640263190403103
# r_star = 0.002517747029842296
# m_star = 0.026198916429639355
# fitness =  [0, 0]
# Phi at the end of iteration = 15.20399999999877
# Phi_min = 6.661338147750939e-16
# (Start point, End point) = (15.20399999999877, 1.3520000000000016)
# efold = 1314465.4245659432
# N_star = 53.967720972325026
# phi_star = 5.151999999999877
# n_star = 0.9640263190403104
# r_star = 0.002517747029842291
# m_star = 0.02619891642963937
# [0, 0]
# 0

# %%
fit_fun(1e-11*sin(sin(tanh(x))))
# Out:
# Current function:  1.0e-11*sin(sin(tanh(x)))
# fitness =  [-3.3491903562021212, 0]
# Phi at the end of iteration = 7.4320063996616765
# Phi_min = -4.9999936003378425
# (Start point, End point) = (7.4320063996616765, 0.8600063996620521)
# efold = 1477246.0779611908
# N_star = 53.82785315242941
# phi_star = 2.384006399662053
# n_star = 0.9655735516431887
# r_star = 0.0005643591452563648
# m_star = 0.025472728036688527
# [-3.3491903562021212, 0]
# 0

# %%
fit_fun(1e-12*tanh(x**2))
# Out:
# Current function:  1.0e-12*tanh(x**2)
# fitness =  0
# Phi at the end of iteration = -3.1199999999999966
# Phi_min = 5.773159728050814e-15
# (Start point, End point) = (-3.1199999999999966, -1.5719999999999954)
# efold = 968476.070134434
# N_star = 53.39245054816401
# phi_star = -2.1079999999999957
# n_star = 0.962921711282199
# r_star = 4.3408639257165786e-05
# m_star = 0.024638028795887824
# fitness =  [0, 0]
# Phi at the end of iteration = 3.120000000000008
# Phi_min = 5.773159728050814e-15
# (Start point, End point) = (3.120000000000008, 1.572000000000007)
# efold = 968476.0701344302
# N_star = 53.39245054816401
# phi_star = 2.108000000000007
# n_star = 0.9629217112822137
# r_star = 4.340863925713135e-05
# m_star = 0.024638028795892712
# [0, 0]
# 0

# %%
fit_fun(3.7e-12*tanh(2*x))
# Out:
# Current function:  3.7e-12*tanh(2*x)
# fitness =  [-2.6848913217933847, 0]
# Phi at the end of iteration = 4.160004904751951
# Phi_min = -4.999995095247928
# (Start point, End point) = (4.160004904751951, 0.8440049047519665)
# efold = 1053290.83104776
# N_star = 53.72280781677253
# phi_star = 1.7040049047519672
# n_star = 0.9649831805191234
# r_star = 0.00015344015762419055
# m_star = 0.02963017569760158
# [-2.6848913217933847, 0]
# 0

# %%
fit_fun(1.0e-11*sin(tanh(tanh(x))))
# Out:
# Current function:  1.0e-11*sin(tanh(tanh(x)))
# fitness =  [-3.349202773918604, 0]
# Phi at the end of iteration = 7.408003969749679
# Phi_min = -4.999996030249843
# (Start point, End point) = (7.408003969749679, 0.8480039697500515)
# efold = 1543582.4488999476
# N_star = 53.81618912064516
# phi_star = 2.3400039697500525
# n_star = 0.9658531067967926
# r_star = 0.0005573872595693212
# m_star = 0.0250623538725662
# [-3.349202773918604, 0]
# 0

# %%
fit_fun(1.0e-11*tanh(tanh(tanh(x))))
# Out:
# Current function:  1.0e-11*tanh(tanh(tanh(x)))
# fitness =  [-3.349195537905925, 0]
# Phi at the end of iteration = 7.356004070741366
# Phi_min = -4.999995929258161
# (Start point, End point) = (7.356004070741366, 0.8360040707417332)
# efold = 1593493.399772194
# N_star = 53.80542877304814
# phi_star = 2.280004070741734
# n_star = 0.966058499311494
# r_star = 0.0005454351315989729
# m_star = 0.024748198924600173
# [-3.349195537905925, 0]
# 0

# %%
fit_fun(1.0e-11*tanh(sin(tanh(x))))
# Out:
# Current function:  1.0e-11*tanh(sin(tanh(x)))
# fitness =  [-3.3491831957604448, 0]
# Phi at the end of iteration = 7.3800040389616
# Phi_min = -4.999995961037925
# (Start point, End point) = (7.3800040389616, 0.8520040389619695)
# efold = 1545426.2993500337
# N_star = 53.815812800752056
# phi_star = 2.3200040389619705
# n_star = 0.9659527888523284
# r_star = 0.0005466227914925056
# m_star = 0.02515330076608962
# [-3.3491831957604448, 0]
# 0

# %%
fit_fun(1.0e-11*tanh(x)/sy.sqrt(tanh(x)**2 + 1))
# Out:
# Current function:  1.0e-11*tanh(x)/sqrt(tanh(x)**2 + 1)
# fitness =  [-3.349224852552519, 0]
# Phi at the end of iteration = 7.464006289061596
# Phi_min = -4.999993710937919
# (Start point, End point) = (7.464006289061596, 0.8360062890619754)
# efold = 1520933.0653065522
# N_star = 53.818622254975764
# phi_star = 2.3880062890619764
# n_star = 0.965359206508743
# r_star = 0.0005829086809056838
# m_star = 0.024934211473040726
# [-3.349224852552519, 0]
# 0

# %%
fit_fun(1.0e-11*atan(atan(tanh(x))))
# Out:
# Current function:  1.0e-11*atan(atan(tanh(x)))
# fitness =  [-3.349225594015011, 0]
# Phi at the end of iteration = 7.444006309094954
# Phi_min = -4.999993690904564
# (Start point, End point) = (7.444006309094954, 0.8240063090953308)
# efold = 1573024.538454239
# N_star = 53.80935477565645
# phi_star = 2.352006309095332
# n_star = 0.9653873672351094
# r_star = 0.0005814370981660322
# m_star = 0.024577140724488716
# [-3.349225594015011, 0]
# 0

# %%
fit_fun(1.0e-11*atan(sin(tanh(x))))
# Out:
# Current function:  1.0e-11*atan(sin(tanh(x)))
# fitness =  [-3.3491941190227004, 0]
# Phi at the end of iteration = 7.416006408753672
# Phi_min = -4.999993591245849
# (Start point, End point) = (7.416006408753672, 0.8440064087540459)
# efold = 1527767.4048045448
# N_star = 53.81779970730248
# phi_star = 2.352006408754047
# n_star = 0.9656301653981729
# r_star = 0.0005625145169733357
# m_star = 0.025090083248276298
# [-3.3491941190227004, 0]
# 0

# %%
fit_fun(1.0e-11*tanh(atan(tanh(x))))
# Out:
# Current function:  1.0e-11*tanh(atan(tanh(x)))
# fitness =  [-3.3492167318267723, 0]
# Phi at the end of iteration = 7.412003956136963
# Phi_min = -4.999996043862558
# (Start point, End point) = (7.412003956136963, 0.8280039561373361)
# efold = 1577193.2520324828
# N_star = 53.80765821436111
# phi_star = 2.324003956137337
# n_star = 0.9655052092669482
# r_star = 0.0005733872299877434
# m_star = 0.024570242248203453
# [-3.3492167318267723, 0]
# 0

# %%
fit_fun(1.0e-11*atan(tanh(tanh(x))))
# Out:
# Current function:  1.0e-11*atan(tanh(tanh(x)))
# fitness =  [-3.3492025426823417, 0]
# Phi at the end of iteration = 7.384004020736427
# Phi_min = -4.9999959792630975
# (Start point, End point) = (7.384004020736427, 0.832004020736797)
# efold = 1586839.7449743235
# N_star = 53.80699162638345
# phi_star = 2.304004020736798
# n_star = 0.9658855614259838
# r_star = 0.0005548512039343415
# m_star = 0.024726889299259168
# [-3.3492025426823417, 0]
# 0

# %%
fit_fun(1.0e-11*tan(sin(tanh(x))))
# Out:
# Current function:  1.0e-11*tan(sin(tanh(x)))
# fitness =  [-3.349284888851852, 0]
# Phi at the end of iteration = 7.736004463874537
# Phi_min = -4.999995536124948
# (Start point, End point) = (7.736004463874537, -0.12399553612505443)
# efold = 1204823.9910038626
# N_star = 53.77778419752583
# phi_star = 2.7240044638749477
# n_star = 0.9625459424068034
# r_star = 0.0006998240067577581
# m_star = 0.02671336263635462
# [-3.349284888851852, 0]
# 0

# %%
fit_fun(4.0e-11*cosh(sinh(tanh(x))))
# Out:
# Current function:  4.0e-11*cosh(sinh(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.495999999999507
# Phi_min = 1.9984014443252818e-15
# (Start point, End point) = (-8.495999999999507, -1.8039999999999994)
# efold = 1025238.1814816399
# N_star = 53.94097841254311
# phi_star = -3.588000000000001
# n_star = 0.9642504761059266
# r_star = 0.0006375436590048173
# m_star = 0.029654212426551915
# fitness =  [0, 0]
# Phi at the end of iteration = 8.49599999999951
# Phi_min = 1.9984014443252818e-15
# (Start point, End point) = (8.49599999999951, 1.8040000000000034)
# efold = 1025238.1814816397
# N_star = 53.94097841254312
# phi_star = 3.588000000000005
# n_star = 0.9642504761059266
# r_star = 0.0006375436590048173
# m_star = 0.029654212426551915
# [0, 0]
# 0

# %%
fit_fun(2.0e-11/cos(tanh(x)))
# Out:
# Current function:  2.0e-11/cos(tanh(x))
# fitness =  0
# Phi at the end of iteration = -8.719999999999484
# Phi_min = 4.440892098500626e-16
# (Start point, End point) = (-8.719999999999484, -1.844000000000001)
# efold = 1383807.7218071134
# N_star = 53.839826964647585
# phi_star = -3.6600000000000024
# n_star = 0.9641558869460335
# r_star = 0.0006418415548569009
# m_star = 0.02549193011147469
# fitness =  [0, 0]
# Phi at the end of iteration = 8.719999999999484
# Phi_min = 4.440892098500626e-16
# (Start point, End point) = (8.719999999999484, 1.8440000000000019)
# efold = 1383807.7218071132
# N_star = 53.839826964647585
# phi_star = 3.6600000000000033
# n_star = 0.9641558869460335
# r_star = 0.0006418415548569009
# m_star = 0.02549193011147469
# [0, 0]
# 0

# %%
fit_fun(2.0e-11*sinh(cosh(tanh(x))))
# Out:
# Current function:  2.0e-11*sinh(cosh(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.5559999999995
# Phi_min = 2.220446049250313e-15
# (Start point, End point) = (-8.5559999999995, -1.7679999999999991)
# efold = 1242158.5167138502
# N_star = 53.877503969313885
# phi_star = -3.5520000000000005
# n_star = 0.9642486430078759
# r_star = 0.0006376233804992066
# m_star = 0.02696027606601142
# fitness =  [0, 0]
# Phi at the end of iteration = 8.555999999999504
# Phi_min = 2.220446049250313e-15
# (Start point, End point) = (8.555999999999504, 1.7680000000000036)
# efold = 1242158.51671385
# N_star = 53.877503969313885
# phi_star = 3.552000000000005
# n_star = 0.9642486430078759
# r_star = 0.0006376233804992066
# m_star = 0.02696027606601142
# [0, 0]
# 0

# %%
fit_fun(1.0e-11*cosh(tan(tanh(x))))
# Out:
# Current function:  1.0e-11*cosh(tan(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.975999999999454
# Phi_min = 1.3322676295501878e-15
# (Start point, End point) = (-8.975999999999454, -2.036)
# efold = 1488883.2905600022
# N_star = 53.81516137018572
# phi_star = -3.8760000000000017
# n_star = 0.9639411608700212
# r_star = 0.0006500916243171676
# m_star = 0.024533441344197705
# fitness =  [0, 0]
# Phi at the end of iteration = 8.975999999999457
# Phi_min = 1.3322676295501878e-15
# (Start point, End point) = (8.975999999999457, 2.0360000000000027)
# efold = 1488883.2905600022
# N_star = 53.81516137018572
# phi_star = 3.8760000000000043
# n_star = 0.9639411608700212
# r_star = 0.0006500916243171676
# m_star = 0.024533441344197705
# [0, 0]
# 0

# %%
fit_fun(2.0e-11*cosh(cosh(tanh(x))))
# Out:
# Current function:  2.0e-11*cosh(cosh(tanh(x)))
# fitness =  0
# Phi at the end of iteration = -8.62799999999949
# Phi_min = 2.6645352591003757e-15
# (Start point, End point) = (-8.62799999999949, -1.7999999999999987)
# efold = 1342717.1964175461
# N_star = 53.851181429972556
# phi_star = -3.584
# n_star = 0.9641697531720715
# r_star = 0.0006404064548763881
# m_star = 0.02589060272886779
# fitness =  [0, 0]
# Phi at the end of iteration = 8.627999999999496
# Phi_min = 2.6645352591003757e-15
# (Start point, End point) = (8.627999999999496, 1.800000000000004)
# efold = 1342717.1964175461
# N_star = 53.851181429972556
# phi_star = 3.5840000000000054
# n_star = 0.9641697531720715
# r_star = 0.0006404064548763881
# m_star = 0.02589060272886779
# [0, 0]
# 0

# %%
fit_fun(1.0e-13*x*cosh(x))
# Out:
# Current function:  1.0e-13*x*cosh(x)
# fitness =  [-15, 0]
# Phi at the end of iteration = 4.47600528928363
# Phi_min = -4.999994710716215
# (Start point, End point) = (4.47600528928363, -3.8599947107163244)
# efold = 724.1025386884066
# N_star = 53.94983923401379
# phi_star = -1.3839947107163222
# n_star = 0.9632415443295415
# r_star = 0.001309101110663984
# m_star = 0.025898928545786307
# [-15, 0]
# 0
